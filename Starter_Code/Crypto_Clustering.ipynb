# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
Scaled_Data = StandardScaler().fit_transform(df_market_data)
Scaled_Data
# Out:
# array([[ 5.08529366e-01,  4.93193071e-01,  7.72200433e-01,
#          2.35459633e-01, -6.74950963e-02, -3.55953481e-01,
#         -2.51636882e-01],
#        [ 1.85445894e-01,  9.34445040e-01,  5.58692121e-01,
#         -5.43409317e-02, -2.73482725e-01, -1.15759474e-01,
#         -1.99352110e-01],
#        [ 2.17739616e-02, -7.06336853e-01, -2.16804207e-02,
#         -6.10301536e-02,  8.00452481e-03, -5.50246924e-01,
#         -2.82060506e-01],
#        [-4.07643829e-02, -8.10928066e-01,  2.49457974e-01,
#         -5.03879651e-02, -3.73164019e-01, -4.58258816e-01,
#         -2.95546142e-01],
#        [ 1.19303608e+00,  2.00095907e+00,  1.76061001e+00,
#          5.45842065e-01, -2.91202870e-01, -4.99847761e-01,
#         -2.70316950e-01],
#        [ 8.91870708e-01,  1.32729453e+00,  8.00214184e-01,
#         -5.71478992e-02,  7.78653106e-01, -1.88231917e-01,
#         -2.25532605e-01],
#        [ 1.13972400e-02,  2.57225091e+00,  1.10164693e+00,
# ...

# %%
# Create a DataFrame with the scaled data
df_scaled_data = pd.DataFrame(Scaled_Data, columns = df_market_data.columns)

# Copy the crypto names from the original data
crypto_names = list(df_market_data.index)

# Set the coinid column as index
df_scaled_data['coin_id'] = crypto_names
df_scaled_data = df_scaled_data.set_index('coin_id')

# Display sample data
df_scaled_data.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1,12))

# %%
# Create an empty list to store the inertia values
inertia_values = list()

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
for k in k_values: 
    k_means = KMeans(n_clusters = k)
    k_means.fit(df_scaled_data)
    inertia_values.append(k_means.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
Elbow_curve_dictionary = {'k_values': k_values, 'inertia_values': inertia_values}

# Create a DataFrame with the data to plot the Elbow curve
elbow_curve_df = pd.DataFrame(Elbow_curve_dictionary)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.

elbow_plot = elbow_curve_df['inertia_values'].hvplot.line(
    xlabel = "k",
    ylabel ="inertia",
    title = "Elbow Curve"
)
elbow_plot
# Out:
# :Curve   [index]   (inertia_values)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** Based on the Elbow curve, best value for k is 3
#
# **Question:** Does it differ from the best k value found using the original data?
#
# **Answer:** the line chart for each one is alittle different but still best value for k is 3 for both of them

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
k_model=KMeans(n_clusters= 3, random_state= 1, n_init="auto")

# %%
# Fit the K-Means model using the scaled data
k_model.fit(df_scaled_data)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
pred_clusters = k_model.predict(df_scaled_data)

# Print the resulting array of cluster values.
pred_clusters
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame
df_scaled_cluster = df_scaled_data.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
df_scaled_cluster['pred_clusters']=pred_clusters

# Display sample data
df_scaled_cluster.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.

cluster_plot= df_scaled_cluster.hvplot.scatter(
    x ="price_change_percentage_24h",
    y ="price_change_percentage_7d",
    by = "pred_clusters",
    hover_cols = ["coin_id"]
)
cluster_plot
# Out:
# :NdOverlay   [pred_clusters]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
principal_components = pca.fit_transform(df_scaled_data)
principal_df = pd.DataFrame(principal_components)

# View the first five rows of the DataFrame. 
principal_df.head()
# Out:
#           0         1         2
# 0 -0.600667  0.842760  0.461595
# 1 -0.458261  0.458466  0.952877
# 2 -0.433070 -0.168126 -0.641752
# 3 -0.471835 -0.222660 -0.479053
# 4 -1.157800  2.041209  1.859715

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %%
explained_variance.sum()
# Out:
# 0.895031657030984

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** the total explained variance is 0.895

# %%
# Create a new DataFrame with the PCA data.
pca_df = pd.DataFrame(principal_components,columns= ["PC1", "PC2", "PC3"])

# Copy the crypto names from the original data
crypto_names = df_scaled_data.index

# Set the coinid column as index
pca_df.index = crypto_names

# Display sample data
pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1,12))

# %%
# Create an empty list to store the inertia values
inertia_values = list()

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list

for k in k_values: 
    k_means = KMeans(n_clusters = k)
    k_means.fit(pca_df)
    inertia_values.append(k_means.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
Elbow_curve_dictionary = {'k_values': k_values, 'inertia_values': inertia_values}

# Create a DataFrame with the data to plot the Elbow curve
elbow_curve_df = pd.DataFrame(Elbow_curve_dictionary)
elbow_curve_df
# Out:
#     k_values  inertia_values
# 0          1      256.874086
# 1          2      168.811896
# 2          3      115.918077
# 3          4       49.665497
# 4          5       42.357370
# 5          6       28.079314
# 6          7       26.494225
# 7          8       18.574523
# 8          9       13.908202
# 9         10       10.989680
# 10        11       11.411488

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.

elbow_plot_pca = elbow_curve_df['inertia_values'].hvplot.line(
    xlabel = "k",
    ylabel ="inertia",
    title = "Elbow Curve PCA"
)
elbow_plot_pca
# Out:
# :Curve   [index]   (inertia_values)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** best value fro K is 3
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No it doesnt diffef from the k value, they are both 3

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
k_model=KMeans(n_clusters=3, random_state= 1, n_init="auto")

# %%
# Fit the K-Means model using the PCA data
k_model.fit(pca_df)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
pred_clusters = k_model.predict(pca_df)
pca_df["clusters"] = pred_clusters

# Print the resulting array of cluster values.
pred_clusters
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
pca_df.head()
# Out:
#                    PC1       PC2       PC3  clusters
# coin_id
# bitcoin      -0.600667  0.842760  0.461595         2
# ethereum     -0.458261  0.458466  0.952877         2
# tether       -0.433070 -0.168126 -0.641752         0
# ripple       -0.471835 -0.222660 -0.479053         0
# bitcoin-cash -1.157800  2.041209  1.859715         2

# %%
# Create a copy of the DataFrame with the PCA data
df_pca_data = pca_df.copy()

# Add a new column to the DataFrame with the predicted clusters
df_pca_data['pred_clusters']=pred_clusters

# Display sample data
df_pca_data
# Out:
#                            PC1       PC2       PC3  clusters  pred_clusters
# coin_id
# bitcoin              -0.600667  0.842760  0.461595         2              2
# ethereum             -0.458261  0.458466  0.952877         2              2
# tether               -0.433070 -0.168126 -0.641752         0              0
# ripple               -0.471835 -0.222660 -0.479053         0              0
# bitcoin-cash         -1.157800  2.041209  1.859715         2              2
# binancecoin          -0.516534  1.388377  0.804071         2              2
# chainlink            -0.450711  0.517699  2.846143         2              2
# cardano              -0.345600  0.729439  1.478013         2              2
# litecoin             -0.649468  0.432165  0.600303         2              2
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653         0              0
# crypto-com-chain     -0.248198 -1.376252 -1.462026         0              0
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.

cluster_plot_pca = pca_df.hvplot.scatter(
    x ="PC1", 
    y ="PC2",
    by = "clusters",
    title = "Cryptocurrencies Clusters Using PCA Data",    
    hover_cols = ["coin_id"],
    marker=["hex", "square", "cross", "inverted_triangle"],
)
cluster_plot_pca
# Out:
# :NdOverlay   [clusters]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves

elbow_plot + elbow_plot_pca
# Out:
# :Layout
#    .Curve.Inertia_values.I  :Curve   [index]   (inertia_values)
#    .Curve.Inertia_values.II :Curve   [index]   (inertia_values)

# %%
# Composite plot to contrast the clusters

cluster_plot + cluster_plot_pca
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [pred_clusters]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [clusters]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** First one is spread out in a contained way, second one is consentrated in one area and some of the dots are spread out much more.

# %%
**testing
